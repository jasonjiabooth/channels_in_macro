# %%
from pathlib import Path
import pandas as pd
import re
import xlsxwriter

# %%
inputfolder = Path(r"C:\Users\jasonjia\Dropbox\Projects\channels_in_macro\data\paragraphs_channel")
inputfile = Path("paragraphs_channel_truncated.xlsx")
outputfolder = inputfolder
outputfile = Path("paragraphs_channel_truncated_bold.xlsx")

# %%
keywordlist = ['channel']

# %%
def split_paragraph_by_keywordlist(keywordlist, paragraph, verbose = False):
    # Split paragraph by any keyword in a `keyword list, where lower/uppercases are ignored, so it allows
    # any form of the keyword to appear in the paragraph, without having to convert
    # the paragraph to lowercase (and thus losing all the uppercases when saving it 
    # to excel later on).
    # The output will be a bunch of strings, that goes something like non-keyword chunk -> keyword -> non-keyword chunk.
    
    keywordlist_pattern = '|'.join(keywordlist)
    if verbose:
        print(keywordlist_pattern)
        
    paragraph_chunks = []
    start_index_chunk = 0
    
    matches = re.finditer(keywordlist_pattern, paragraph, flags=re.IGNORECASE)
    if verbose: 
        print(matches)

    number_of_keywords_in_paragraph = len(re.findall(keywordlist_pattern, paragraph, flags=re.IGNORECASE))
    print("number_of_keywords_in_paragraph: ", str(number_of_keywords_in_paragraph))

    for index, match in enumerate(matches):
        if verbose: 
            print(match.string)
            print(match.group())
            print(match.start())
            print(match.end())

        keyword = match.group()
        start_index_keyword = match.start()
        end_index_keyword = match.end()

        paragraph_chunk = paragraph[start_index_chunk:start_index_keyword]
        start_index_chunk = end_index_keyword
        paragraph_chunks.append(paragraph_chunk)
        paragraph_chunks.append(keyword)
        
        if verbose: 
            print("index: ", str(index))
            
        if index == (number_of_keywords_in_paragraph - 1):
            paragraph_chunk = paragraph[start_index_chunk:]
            paragraph_chunks.append(paragraph_chunk)

        if verbose: 
            print(paragraph_chunks)
                
    return paragraph_chunks

# %%
def get_formatted_paragraph_chunks(keywordlist, paragraph, verbose = False):
    # Split paragraph by keyword
    paragraph_chunks = split_paragraph_by_keywordlist(keywordlist, paragraph)
    if verbose == True:
        print("paragraph_chunks: ", paragraph_chunks) 

    # Keep only non-empty strings
    paragraph_chunks = list(filter(None, paragraph_chunks))  
    
    # Initialize final list of paragraph chunks with keyword bolded
    paragraph_chunks_formatted = []
    
    for chunk in paragraph_chunks:
        if verbose == True:
            print("chunk: ", chunk)
            
        if any(chunk.lower() == keyword for keyword in keywordlist):
            paragraph_chunks_formatted.append(bold_format_paragraph)
        else:
            paragraph_chunks_formatted.append(non_bold_format_paragraph)
        
        paragraph_chunks_formatted.append(chunk)
        if verbose == True:
            print("paragraph_chunks_formatted:", paragraph_chunks_formatted)
        

    if verbose == True:
        print("paragraph_chunks_formatted - final:", paragraph_chunks_formatted)

    return paragraph_chunks_formatted

# %%
# Import channels df
channels_df = pd.read_excel(Path(inputfolder / inputfile))

# Check that the last column is 'Paragraph', because it is needed for subsequent code to run correctly
if channels_df.columns.values[-1] != 'Paragraph':
    print("Warning: Last column of channels_df is not 'Paragraph'. Subsequent code won't work as expected.\n")

# Get last column of df (0-indexed)
paragraph_col_index_number = channels_df.shape[1] - 1
number_of_paragraphs = channels_df.shape[0] - 1

# %%
# Create workbook (output excel file)
workbook = xlsxwriter.Workbook(Path(outputfolder / outputfile))
worksheet = workbook.add_worksheet()

# Create bold format for column headers
bold_format_col_headers = workbook.add_format({'bold': True, "align":"center", "valign":"center"})

# Create bold format for keywords in paragraph
bold_format_paragraph = workbook.add_format({'bold': True})

# Create non-bold format for non-keywords in paragraph
non_bold_format_paragraph = workbook.add_format({'bold': False})

# Create wrap text format for column
wrap_text_format_col = workbook.add_format({'text_wrap': True})

# Set column widths - 'Paragraph' should be the last column
column_widths = [25, 30, 30, 10, 20, 140]

# Set row height
row_height = 15

# Set column width of all columns and turn wrap_text on
for index, width in enumerate(column_widths):
    worksheet.set_column(first_col = index, last_col = index, 
                         width = width, cell_format = wrap_text_format_col)
    
# Set row_heights of all rows
for i in range(number_of_paragraphs):
    worksheet.set_column(number_of_paragraphs + 1, row_height) # arguments: row, (row) height

# %%
# Write first row (column header)
worksheet.write_row(row = 0, col = 0, data = channels_df.columns.values, cell_format = bold_format_col_headers)

# Write rest of rows (paragraphs) - 'Paragraph' should be the last column
for index, row in channels_df.iterrows():
    paragraph = row['Paragraph']
    print(row['Title'])
    worksheet.write_row(row = index + 1, col = 0, data = row.drop('Paragraph'))
    paragraph_chunks_formatted = get_formatted_paragraph_chunks(keywordlist, paragraph)
    worksheet.write_rich_string(index + 1, paragraph_col_index_number, *paragraph_chunks_formatted)

workbook.close()
# Out:
# Sectoral Media Focus and Aggregate Fluctuations.
# number_of_keywords_in_paragraph:  1
# Sectoral Media Focus and Aggregate Fluctuations.
# number_of_keywords_in_paragraph:  1
# Sectoral Media Focus and Aggregate Fluctuations.
# number_of_keywords_in_paragraph:  1
# Sectoral Media Focus and Aggregate Fluctuations.
# number_of_keywords_in_paragraph:  2
# Product Innovation, Product Diversification, and Firm Growth: Evidence from Japan's Early Industrialization.
# number_of_keywords_in_paragraph:  1
# Product Innovation, Product Diversification, and Firm Growth: Evidence from Japan's Early Industrialization.
# number_of_keywords_in_paragraph:  1
# Product Innovation, Product Diversification, and Firm Growth: Evidence from Japan's Early Industrialization.
# number_of_keywords_in_paragraph:  2
# Venting Out: Exports during a Domestic Slump.
# number_of_keywords_in_paragraph:  1
# Venting Out: Exports during a Domestic Slump.
# number_of_keywords_in_paragraph:  1
# Venting Out: Exports during a Domestic Slump.
# number_of_keywords_in_paragraph:  2
# Venting Out: Exports during a Domestic Slump.
# number_of_keywords_in_paragraph:  2
# Labor Rationing.
# number_of_keywords_in_paragraph:  1
# Labor Rationing.
# number_of_keywords_in_paragraph:  1
# The Effect of -High-Tech Clusters on the Productivity of Top Inventors.
# number_of_keywords_in_paragraph:  1
# From Mad Men to Maths Men: Concentration and Buyer Power in Online Advertising.
# number_of_keywords_in_paragraph:  1
# From Mad Men to Maths Men: Concentration and Buyer Power in Online Advertising.
# number_of_keywords_in_paragraph:  2
# From Weber to Kafka: Political Instability and the Overproduction of Laws.
# number_of_keywords_in_paragraph:  1
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  1
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  4
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  2
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  2
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  1
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  1
# Mortgage Prepayment and Path-Dependent Effects of Monetary Policy.
# number_of_keywords_in_paragraph:  1
# What to Expect from the Lower Bound on Interest Rates: Evidence from Derivatives Prices.
# number_of_keywords_in_paragraph:  1
# What to Expect from the Lower Bound on Interest Rates: Evidence from Derivatives Prices.
# number_of_keywords_in_paragraph:  1
# Lapse-Based Insurance.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# On Her Own Account: How Strengthening Women's Financial Control Impacts Labor Supply and Gender Norms.
# number_of_keywords_in_paragraph:  1
# Security Transitions.
# number_of_keywords_in_paragraph:  1
# Security Transitions.
# number_of_keywords_in_paragraph:  1
# The Selection of Talent: Experimental and Structural Evidence from Ethiopia.
# number_of_keywords_in_paragraph:  1
# The Selection of Talent: Experimental and Structural Evidence from Ethiopia.
# number_of_keywords_in_paragraph:  1
# The Selection of Talent: Experimental and Structural Evidence from Ethiopia.
# number_of_keywords_in_paragraph:  2
# The Selection of Talent: Experimental and Structural Evidence from Ethiopia.
# number_of_keywords_in_paragraph:  1
# The Selection of Talent: Experimental and Structural Evidence from Ethiopia.
# number_of_keywords_in_paragraph:  2
# Feedbacks: Financial Markets and Economic Activity.
# number_of_keywords_in_paragraph:  1
# Feedbacks: Financial Markets and Economic Activity.
# number_of_keywords_in_paragraph:  1
# Feedbacks: Financial Markets and Economic Activity.
# number_of_keywords_in_paragraph:  1
# Feedbacks: Financial Markets and Economic Activity.
# number_of_keywords_in_paragraph:  1
# Feedbacks: Financial Markets and Economic Activity.
# number_of_keywords_in_paragraph:  2
# Five Facts about Beliefs and Portfolios.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  3
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Stock Market Wealth and the Real Economy: A Local Labor Market Approach.
# number_of_keywords_in_paragraph:  1
# Cross-Region Transfer Multipliers in a Monetary Union: Evidence from Social Security and Stimulus Payments.
# number_of_keywords_in_paragraph:  1
# Myopia and Anchoring.
# number_of_keywords_in_paragraph:  1
# Myopia and Anchoring.
# number_of_keywords_in_paragraph:  1
# Myopia and Anchoring.
# number_of_keywords_in_paragraph:  1
# Myopia and Anchoring.
# number_of_keywords_in_paragraph:  3
# Myopia and Anchoring.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  2
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  2
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# The Macroeconomic Effects of Oil Supply News: Evidence from OPEC Announcements.
# number_of_keywords_in_paragraph:  1
# Self-Fulfilling Debt Crises: A Quantitative Analysis.
# number_of_keywords_in_paragraph:  4
# Self-Fulfilling Debt Crises: A Quantitative Analysis.
# number_of_keywords_in_paragraph:  3
# Liquidity Sentiments.
# number_of_keywords_in_paragraph:  1
# The Paradox of Global Thrift.
# number_of_keywords_in_paragraph:  1
# The Paradox of Global Thrift.
# number_of_keywords_in_paragraph:  1
# The Paradox of Global Thrift.
# number_of_keywords_in_paragraph:  1
# The Paradox of Global Thrift.
# number_of_keywords_in_paragraph:  2
# Monetary Policy, Bounded Rationality, and Incomplete Markets.
# number_of_keywords_in_paragraph:  1
# Equilibrium Effects of Firm Subsidies.
# number_of_keywords_in_paragraph:  1
# Is Inflation Default? The Role of Information in Debt Crises.
# number_of_keywords_in_paragraph:  1
# Is Inflation Default? The Role of Information in Debt Crises.
# number_of_keywords_in_paragraph:  1
# Is Inflation Default? The Role of Information in Debt Crises.
# number_of_keywords_in_paragraph:  1
# Is Inflation Default? The Role of Information in Debt Crises.
# number_of_keywords_in_paragraph:  1
# Is Inflation Default? The Role of Information in Debt Crises.
# number_of_keywords_in_paragraph:  1
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  5
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  3
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  2
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  2
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  5
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  1
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  2
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  1
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  2
# Firms' Internal Networks and Local Economic Shocks.
# number_of_keywords_in_paragraph:  1
# Nominal Wage Rigidity in Village Labor Markets.
# number_of_keywords_in_paragraph:  1
# Nominal Wage Rigidity in Village Labor Markets.
# number_of_keywords_in_paragraph:  1
# Nominal Wage Rigidity in Village Labor Markets.
# number_of_keywords_in_paragraph:  1
# Nominal Wage Rigidity in Village Labor Markets.
# number_of_keywords_in_paragraph:  1
# Competition and Strategic Incentives in the Market for Credit Ratings: Empirics of the Financial Crisis of 2007.
# number_of_keywords_in_paragraph:  1
# The Financial Transmission of Housing Booms: Evidence from Spain.
# number_of_keywords_in_paragraph:  1
# The Financial Transmission of Housing Booms: Evidence from Spain.
# number_of_keywords_in_paragraph:  1
# The Financial Transmission of Housing Booms: Evidence from Spain.
# number_of_keywords_in_paragraph:  1
# The Abolition of Immigration Restrictions and the Performance of Firms and Workers: Evidence from Switzerland.
# number_of_keywords_in_paragraph:  1
# The Abolition of Immigration Restrictions and the Performance of Firms and Workers: Evidence from Switzerland.
# number_of_keywords_in_paragraph:  1
# The Abolition of Immigration Restrictions and the Performance of Firms and Workers: Evidence from Switzerland.
# number_of_keywords_in_paragraph:  1
# Exchange Rates and Prices: Evidence from the 2015 Swiss Franc Appreciation.
# number_of_keywords_in_paragraph:  1
# Intertemporal Labor Supply Substitution? Evidence from the Swiss Income Tax Holidays.
# number_of_keywords_in_paragraph:  1
# Intertemporal Labor Supply Substitution? Evidence from the Swiss Income Tax Holidays.
# number_of_keywords_in_paragraph:  1
# Intertemporal Labor Supply Substitution? Evidence from the Swiss Income Tax Holidays.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  6
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  2
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  3
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  3
# Going Negative at the Zero Lower Bound: The Effects of Negative Nominal Interest Rates.
# number_of_keywords_in_paragraph:  1
# Mobilizing the Masses for Genocide.
# number_of_keywords_in_paragraph:  1
# Mobilizing the Masses for Genocide.
# number_of_keywords_in_paragraph:  1
# Mobilizing the Masses for Genocide.
# number_of_keywords_in_paragraph:  1
# Mobilizing the Masses for Genocide.
# number_of_keywords_in_paragraph:  1
# Mobilizing the Masses for Genocide.
# number_of_keywords_in_paragraph:  1
# Bank Networks and Systemic Risk: Evidence from the National Banking Acts.
# number_of_keywords_in_paragraph:  1
# Bank Networks and Systemic Risk: Evidence from the National Banking Acts.
# number_of_keywords_in_paragraph:  1
# Bank Networks and Systemic Risk: Evidence from the National Banking Acts.
# number_of_keywords_in_paragraph:  1
# Bank Networks and Systemic Risk: Evidence from the National Banking Acts.
# number_of_keywords_in_paragraph:  2
# Brands in Motion: How Frictions Shape Multinational Production.
# number_of_keywords_in_paragraph:  1
# Consumers as Tax Auditors.
# number_of_keywords_in_paragraph:  1
# Consumers as Tax Auditors.
# number_of_keywords_in_paragraph:  1
# Consumers as Tax Auditors.
# number_of_keywords_in_paragraph:  1
# Consumers as Tax Auditors.
# number_of_keywords_in_paragraph:  2
# Consumers as Tax Auditors.
# number_of_keywords_in_paragraph:  1
# Slow Moving Debt Crises.
# number_of_keywords_in_paragraph:  1
# Who Pays for the Minimum Wage?
# number_of_keywords_in_paragraph:  2
# Who Pays for the Minimum Wage?
# number_of_keywords_in_paragraph:  1
# Who Pays for the Minimum Wage?
# number_of_keywords_in_paragraph:  1
# The Sources of Capital Misallocation.
# number_of_keywords_in_paragraph:  1
# Consumer Spending during Unemployment: Positive and Normative Implications.
# number_of_keywords_in_paragraph:  1
# Consumer Spending during Unemployment: Positive and Normative Implications.
# number_of_keywords_in_paragraph:  1
# Disability Benefits, Consumption Insurance, and Household Labor Supply.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  2
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  2
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  3
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  2
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  2
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  2
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Political Legacy of Entertainment TV.
# number_of_keywords_in_paragraph:  1
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  1
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  2
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  1
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  2
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  1
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  3
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  2
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  3
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  2
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  3
# The Effect of House Prices on Household Borrowing: A New Approach.
# number_of_keywords_in_paragraph:  1
# Tax Evasion and Inequality.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  2
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  2
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  2
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  2
# Tourism and Economic Development: Evidence from Mexico's Coastline.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  5
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  2
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  4
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  2
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  3
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  6
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  6
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  2
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  1
# Monetary Policy and the Redistribution Channel.
# number_of_keywords_in_paragraph:  2
# A Macroeconomic Model of Price Swings in the Housing Market.
# number_of_keywords_in_paragraph:  1
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  1
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  2
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  6
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  2
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  1
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  1
# Payroll Taxes, Firm Behavior, and Rent Sharing: Evidence from a Young Workers' Tax Cut in Sweden.
# number_of_keywords_in_paragraph:  3
# Wealth Distribution and Social Mobility in the US: A Quantitative Approach.
# number_of_keywords_in_paragraph:  1
# Trade, Migration, and Productivity: A Quantitative Analysis of China.
# number_of_keywords_in_paragraph:  1
# (Mis)Allocation, Market Power, and Global Oil Extraction.
# number_of_keywords_in_paragraph:  1
# Alcohol and Self-Control: A Field Experiment in India.
# number_of_keywords_in_paragraph:  1
# Alcohol and Self-Control: A Field Experiment in India.
# number_of_keywords_in_paragraph:  1
# Alcohol and Self-Control: A Field Experiment in India.
# number_of_keywords_in_paragraph:  1
# Vulnerable Growth.
# number_of_keywords_in_paragraph:  2
# Vulnerable Growth.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  3
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  2
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  2
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Discounts and Deadlines in Consumer Search.
# number_of_keywords_in_paragraph:  1
# Missing Events in Event Studies: Identifying the Effects of Partially Measured News Surprises.
# number_of_keywords_in_paragraph:  2
# How Well Targeted Are Soda Taxes?
# number_of_keywords_in_paragraph:  1
# How Well Targeted Are Soda Taxes?
# number_of_keywords_in_paragraph:  1
# How Well Targeted Are Soda Taxes?
# number_of_keywords_in_paragraph:  1
# Methods Matter: p-Hacking and Publication Bias in Causal Analysis in Economics.
# number_of_keywords_in_paragraph:  1
# Small and Large Firms over the Business Cycle.
# number_of_keywords_in_paragraph:  2
# Small and Large Firms over the Business Cycle.
# number_of_keywords_in_paragraph:  1
# Small and Large Firms over the Business Cycle.
# number_of_keywords_in_paragraph:  1
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  1
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  2
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  2
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  1
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  1
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  1
# Devotion and Development: Religiosity, Education, and Economic Progress in Nineteenth-Century France.
# number_of_keywords_in_paragraph:  1
# Does Information Break the Political Resource Curse? Experimental Evidence from Mozambique.
# number_of_keywords_in_paragraph:  1
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  2
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  1
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  1
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  1
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  1
# Arrival of Young Talent: The Send-Down Movement and Rural Education in China.
# number_of_keywords_in_paragraph:  1
# Seasonal Liquidity, Rural Labor Markets, and Agricultural Production.
# number_of_keywords_in_paragraph:  1
# Seasonal Liquidity, Rural Labor Markets, and Agricultural Production.
# number_of_keywords_in_paragraph:  1
# Seasonal Liquidity, Rural Labor Markets, and Agricultural Production.
# number_of_keywords_in_paragraph:  1
# Seasonal Liquidity, Rural Labor Markets, and Agricultural Production.
# number_of_keywords_in_paragraph:  1
# Sources of Inaction in Household Finance: Evidence from the Danish Mortgage Market.
# number_of_keywords_in_paragraph:  1
# Sources of Inaction in Household Finance: Evidence from the Danish Mortgage Market.
# number_of_keywords_in_paragraph:  1
# Sources of Inaction in Household Finance: Evidence from the Danish Mortgage Market.
# number_of_keywords_in_paragraph:  1
# Sources of Inaction in Household Finance: Evidence from the Danish Mortgage Market.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  2
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  2
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Importing Political Polarization? The Electoral Consequences of Rising Trade Exposure.
# number_of_keywords_in_paragraph:  1
# Liquidity versus Wealth in Household Debt Obligations: Evidence from Housing Policy in the Great Recession.
# number_of_keywords_in_paragraph:  1
# Liquidity versus Wealth in Household Debt Obligations: Evidence from Housing Policy in the Great Recession.
# number_of_keywords_in_paragraph:  4
# Liquidity versus Wealth in Household Debt Obligations: Evidence from Housing Policy in the Great Recession.
# number_of_keywords_in_paragraph:  1
# Liquidity versus Wealth in Household Debt Obligations: Evidence from Housing Policy in the Great Recession.
# number_of_keywords_in_paragraph:  2
# Misperceived Social Norms: Women Working Outside the Home in Saudi Arabia.
# number_of_keywords_in_paragraph:  2
# How Do Individuals Repay Their Debt? The Balance-Matching Heuristic.
# number_of_keywords_in_paragraph:  1
# The Arrival of Fast Internet and Employment in Africa.
# number_of_keywords_in_paragraph:  2
# The Arrival of Fast Internet and Employment in Africa.
# number_of_keywords_in_paragraph:  1
# The Arrival of Fast Internet and Employment in Africa.
# number_of_keywords_in_paragraph:  1
# The Arrival of Fast Internet and Employment in Africa.
# number_of_keywords_in_paragraph:  1
# The Arrival of Fast Internet and Employment in Africa.
# number_of_keywords_in_paragraph:  1
# Does Household Finance Matter? Small Financial Errors with Large Social Costs.
# number_of_keywords_in_paragraph:  1
# Does Household Finance Matter? Small Financial Errors with Large Social Costs.
# number_of_keywords_in_paragraph:  1
# Does Household Finance Matter? Small Financial Errors with Large Social Costs.
# number_of_keywords_in_paragraph:  2
# Does Household Finance Matter? Small Financial Errors with Large Social Costs.
# number_of_keywords_in_paragraph:  1
# The Social Value of Financial Expertise.
# number_of_keywords_in_paragraph:  1
# The Social Value of Financial Expertise.
# number_of_keywords_in_paragraph:  1
# The Social Value of Financial Expertise.
# number_of_keywords_in_paragraph:  2
# The Social Value of Financial Expertise.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  4
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  1
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  4
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  2
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# Recovery from the Great Depression: The Farm Channel in Spring 1933.
# number_of_keywords_in_paragraph:  3
# The Taxing Deed of Globalization.
# number_of_keywords_in_paragraph:  1
# The Taxing Deed of Globalization.
# number_of_keywords_in_paragraph:  1
# The Taxing Deed of Globalization.
# number_of_keywords_in_paragraph:  1
# The Taxing Deed of Globalization.
# number_of_keywords_in_paragraph:  1
# The Long-Term Effects of Management and Technology Transfers.
# number_of_keywords_in_paragraph:  1
# The Long-Term Effects of Management and Technology Transfers.
# number_of_keywords_in_paragraph:  1
# The Long-Term Effects of Management and Technology Transfers.
# number_of_keywords_in_paragraph:  1
# The Long-Term Effects of Management and Technology Transfers.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  2
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  3
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  2
# Optimal Regulation of Financial Intermediaries.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# The Nexus of Monetary Policy and Shadow Banking in China.
# number_of_keywords_in_paragraph:  1
# Bad Investments and Missed Opportunities? Postwar Capital Flows to Asia and Latin America.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  2
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  2
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# Why Is Pollution from US Manufacturing Declining? The Roles of Environmental Regulation, Productivity, and Trade.
# number_of_keywords_in_paragraph:  1
# The Costs of Patronage: Evidence from the British Empire.
# number_of_keywords_in_paragraph:  1
# The Costs of Patronage: Evidence from the British Empire.
# number_of_keywords_in_paragraph:  1
# The Costs of Patronage: Evidence from the British Empire.
# number_of_keywords_in_paragraph:  2
# The Costs of Patronage: Evidence from the British Empire.
# number_of_keywords_in_paragraph:  1
# The Costs of Patronage: Evidence from the British Empire.
# number_of_keywords_in_paragraph:  1
# Mismatch of Talent: Evidence on Match Quality, Entry Wages, and Job Mobility.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  2
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# Temporary Protection and Technology Adoption: Evidence from the Napoleonic Blockade.
# number_of_keywords_in_paragraph:  1
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  6
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  1
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  2
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  1
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  1
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  5
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  2
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  2
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  1
# BKK the EZ Way: International Long-Run Growth News and Capital Flows.
# number_of_keywords_in_paragraph:  3
# Moved to Opportunity: The Long-Run Effects of Public Housing Demolition on Children.
# number_of_keywords_in_paragraph:  1
# Housing Booms and Busts, Labor Market Opportunities, and College Attendance.
# number_of_keywords_in_paragraph:  2
# Housing Booms and Busts, Labor Market Opportunities, and College Attendance.
# number_of_keywords_in_paragraph:  1
# Nonrivalry and the Economics of Data.
# number_of_keywords_in_paragraph:  1
# Policy Language and Information Effects in the Early Days of Federal Reserve Forward Guidance.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  2
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Household Debt Revaluation and the Real Economy: Evidence from a Foreign Currency Debt Crisis.
# number_of_keywords_in_paragraph:  1
# Rich Pickings? Risk, Return, and Skill in Household Wealth.
# number_of_keywords_in_paragraph:  1
# Rich Pickings? Risk, Return, and Skill in Household Wealth.
# number_of_keywords_in_paragraph:  3
# Rich Pickings? Risk, Return, and Skill in Household Wealth.
# number_of_keywords_in_paragraph:  1
# Rich Pickings? Risk, Return, and Skill in Household Wealth.
# number_of_keywords_in_paragraph:  1
# Rich Pickings? Risk, Return, and Skill in Household Wealth.
# number_of_keywords_in_paragraph:  1
# An Estimated Structural Model of Entrepreneurial Behavior.
# number_of_keywords_in_paragraph:  1
# Subsidy Policies and Insurance Demand.
# number_of_keywords_in_paragraph:  1
# Subsidy Policies and Insurance Demand.
# number_of_keywords_in_paragraph:  2
# Bartik Instruments: What, When, Why, and How.
# number_of_keywords_in_paragraph:  2
# Bartik Instruments: What, When, Why, and How.
# number_of_keywords_in_paragraph:  1
# Financial Crises, Dollarization, and Lending of Last Resort in Open Economies.
# number_of_keywords_in_paragraph:  1
# Long-Run Growth of Financial Data Technology.
# number_of_keywords_in_paragraph:  2
# Long-Run Growth of Financial Data Technology.
# number_of_keywords_in_paragraph:  5
# Long-Run Growth of Financial Data Technology.
# number_of_keywords_in_paragraph:  1
# A Behavioral New Keynesian Model.
# number_of_keywords_in_paragraph:  1
# A Behavioral New Keynesian Model.
# number_of_keywords_in_paragraph:  2
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  2
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  1
# Home Values and Firm Behavior.
# number_of_keywords_in_paragraph:  2
# Risk Premia and the Real Effects of Money.
# number_of_keywords_in_paragraph:  1
# Risk Premia and the Real Effects of Money.
# number_of_keywords_in_paragraph:  1
# Asset Bubbles and Credit Constraints.
# number_of_keywords_in_paragraph:  1
# How Do Firms Form Their Expectations? New Survey Evidence.
# number_of_keywords_in_paragraph:  1
# How Do Firms Form Their Expectations? New Survey Evidence.
# number_of_keywords_in_paragraph:  1
# How Do Firms Form Their Expectations? New Survey Evidence.
# number_of_keywords_in_paragraph:  1
# How Do Firms Form Their Expectations? New Survey Evidence.
# number_of_keywords_in_paragraph:  1
# In Search of Labor Demand.
# number_of_keywords_in_paragraph:  1
# In Search of Labor Demand.
# number_of_keywords_in_paragraph:  2
# International Reserves and Rollover Risk.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# Fiscal Foundations of Inflation: Imperfect Knowledge.
# number_of_keywords_in_paragraph:  1
# ...
# number_of_keywords_in_paragraph:  1
# The Impact of Regional and Sectoral Productivity Changes on the U.S. Economy.
# number_of_keywords_in_paragraph:  1
# The Impact of Regional and Sectoral Productivity Changes on the U.S. Economy.
# number_of_keywords_in_paragraph:  1
# The Impact of Regional and Sectoral Productivity Changes on the U.S. Economy.
# number_of_keywords_in_paragraph:  1
# The Impact of Regional and Sectoral Productivity Changes on the U.S. Economy.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  2
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  3
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  1
# Wealth and Volatility.
# number_of_keywords_in_paragraph:  2
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  3
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  1
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  1
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  1
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  2
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  4
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  6
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  1
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  2
# Optimal Fiscal Policy with Recursive Preferences.
# number_of_keywords_in_paragraph:  1
# Better Lucky Than Rich? Welfare Analysis of Automobile Licence Allocations in Beijing and Shanghai.
# number_of_keywords_in_paragraph:  1
# The Role of Firm Factors in Demand, Cost, and Export Market Selection for Chinese Footwear Producers.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  2
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Attention Variation and Welfare: Theory and Evidence from a Tax Salience Experiment.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  1
# Stagnation Traps.
# number_of_keywords_in_paragraph:  2
# House Prices and Consumer Spending.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  2
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  4
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  3
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  2
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  2
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  2
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  1
# Aggregate Implications of Corporate Debt Choices.
# number_of_keywords_in_paragraph:  2
# Asset Prices and Portfolio Choice with Learning from Experience.
# number_of_keywords_in_paragraph:  1
# Asset Prices and Portfolio Choice with Learning from Experience.
# number_of_keywords_in_paragraph:  1
# Deadly Embrace: Sovereign and Financial Balance Sheets Doom Loops.
# number_of_keywords_in_paragraph:  2
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model.
# number_of_keywords_in_paragraph:  1
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model.
# number_of_keywords_in_paragraph:  1
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model.
# number_of_keywords_in_paragraph:  1
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model.
# number_of_keywords_in_paragraph:  2
# Immigration, Wages, and Education: A Labour Market Equilibrium Structural Model.
# number_of_keywords_in_paragraph:  1
# Dutch Disease or Agglomeration? The Local Economic Effects of Natural Resource Booms in Modern America.
# number_of_keywords_in_paragraph:  3
# Dutch Disease or Agglomeration? The Local Economic Effects of Natural Resource Booms in Modern America.
# number_of_keywords_in_paragraph:  1
# Dutch Disease or Agglomeration? The Local Economic Effects of Natural Resource Booms in Modern America.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  8
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  2
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  2
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  3
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  2
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  4
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  2
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  3
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Evaluating Long-Term-Care Policy Options, Taking the Family Seriously.
# number_of_keywords_in_paragraph:  1
# Uncertainty Shocks, Asset Supply and Pricing over the Business Cycle.
# number_of_keywords_in_paragraph:  1
# The (Q,S,s) Pricing Rule.
# number_of_keywords_in_paragraph:  2
# The (Q,S,s) Pricing Rule.
# number_of_keywords_in_paragraph:  1
# The (Q,S,s) Pricing Rule.
# number_of_keywords_in_paragraph:  1
# Quantifying Loss-Averse Tax Manipulation.
# number_of_keywords_in_paragraph:  1
# Quantifying Loss-Averse Tax Manipulation.
# number_of_keywords_in_paragraph:  1
# Quantifying Loss-Averse Tax Manipulation.
# number_of_keywords_in_paragraph:  1
# Quantifying Loss-Averse Tax Manipulation.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  2
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  2
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Reallocation, Competition, and Productivity: Evidence from a Financial Liberalization Episode.
# number_of_keywords_in_paragraph:  1
# Applications and Interviews: Firms' Recruiting Decisions in a Frictional Labour Market.
# number_of_keywords_in_paragraph:  1
# Myopic Agency.
# number_of_keywords_in_paragraph:  1
# Myopic Agency.
# number_of_keywords_in_paragraph:  1
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  1
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  1
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  1
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  3
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  2
# The Pruned State-Space System for Non-Linear DSGE Models: Theory and Empirical Applications.
# number_of_keywords_in_paragraph:  2
# Reconciling Hayek's and Keynes'Views of Recessions.
# number_of_keywords_in_paragraph:  1
# Reconciling Hayek's and Keynes'Views of Recessions.
# number_of_keywords_in_paragraph:  1
# Housing Market Responses to Transaction Taxes: Evidence From Notches and Stimulus in the U.K.
# number_of_keywords_in_paragraph:  1
# Housing Market Responses to Transaction Taxes: Evidence From Notches and Stimulus in the U.K.
# number_of_keywords_in_paragraph:  1
# The Safety Trap.
# number_of_keywords_in_paragraph:  1
# The Safety Trap.
# number_of_keywords_in_paragraph:  1
# Adverse Selection and Liquidity Distortion.
# number_of_keywords_in_paragraph:  3
# Adverse Selection and Liquidity Distortion.
# number_of_keywords_in_paragraph:  1
# Two-Sided Learning and the Ratchet Principle.
# number_of_keywords_in_paragraph:  1
# Pecuniary Externalities in Economies with Financial Frictions.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  2
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  13
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  2
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  2
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  4
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  2
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# The Effects of Banning Advertising in Junk Food Markets.
# number_of_keywords_in_paragraph:  1
# Portfolio Choices, Firm Shocks, and Uninsurable Wage Risk.
# number_of_keywords_in_paragraph:  1
# Portfolio Choices, Firm Shocks, and Uninsurable Wage Risk.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  2
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# International Arbitrage and the Extensive Margin of Trade between Rich and Poor Countries.
# number_of_keywords_in_paragraph:  1
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     322             try:
# --> 323                 self._store_workbook()
#     324             except IOError as e:
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     657         except IOError as e:
# --> 658             raise e
#     659
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     654         try:
# --> 655             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     656                                 allowZip64=self.allow_zip64)
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1238                 try:
# -> 1239                     self.fp = io.open(file, filemode)
#    1240                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\jasonjia\\Dropbox\\Projects\\channels_in_macro\\data\\paragraphs_channel\\paragraphs_channel_truncated_bold.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14032/1397420181.py in <module>
#      10     worksheet.write_rich_string(index + 1, paragraph_col_index_number, *paragraph_chunks_formatted)
#      11
# ---> 12 workbook.close()
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     323                 self._store_workbook()
#     324             except IOError as e:
# --> 325                 raise FileCreateError(e)
#     326             except LargeZipFile as e:
#     327                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: 'C:\\Users\\jasonjia\\Dropbox\\Projects\\channels_in_macro\\data\\paragraphs_channel\\paragraphs_channel_truncated_bold.xlsx'

# %% [markdown]
# ## Tests

# %%
paragraph_chunks_formatted = get_formatted_paragraph_chunks(keywordlist, "channel acts in the same direction as the substitution channel, and with comparable magnitude provided that ​σ​ is between ​0.1​and ​0.4​. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if ​σ​ is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher channel. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity channel also amplifies the effects of monetary policy. Future work can build on these empirical results in two ways: by providing more precise measures of exposures across groups of agents or regions to inform the debate on the winners and losers from changes in monetary policy, and by estimat-ing the sufficient statistics more precisely in administrative data to help quantify the aggregate effect of this redistribution.4 A rapidly growing literature analyzes the effects of monetary policy in dynamic stochastic general equilibrium models with rich heterogeneity, matching vari-ous aspects of the cross section such as the wealth distribution. Prominent exam-ples include Gornemann, Kuester, and Nakajima (2016); McKay, Nakamura, and Steinsson (2016); and Kaplan, Moll, and Violante (2018). These structural mod-els overcome a number of important limitations of my sufficient statistics approach. They can study the role of investment, analyze the precise interaction between mon-etary and fiscal policy, and explore the effect of shocks that are persistent and/or announced in advance. My paper makes two contributions to this literature. First, I introduce a decomposition of the monetary policy transmission mechanism into its various sources of effects on consumption that is useful to shed light on the under-lying mechanisms in any such model (see Kaplan, Moll, and Violante 2018 for an influential application). Second, I argue that sufficient statistics can discipline the construction of these models. By making sure that the model’s sufficient statistics match the data, researchers can ensure that, even if the model is misspecified, its predictions for the response of consumption to shocks are consistent with the empir-ical evidence. This paper is motivated by an extensive empirical literature documenting that MPCs are large and heterogeneous in the population (see Jappelli and Pistaferri 2010", True)
# Out:
# number_of_keywords_in_paragraph:  4
# paragraph_chunks:  ['', 'channel', ' acts in the same direction as the substitution ', 'channel', ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', 'channel', '. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity ', 'channel', ' also amplifies the effects of monetary policy. Future work can build on these empirical results in two ways: by providing more precise measures of exposures across groups of agents or regions to inform the debate on the winners and losers from changes in monetary policy, and by estimat-ing the sufficient statistics more precisely in administrative data to help quantify the aggregate effect of this redistribution.4 A rapidly growing literature analyzes the effects of monetary policy in dynamic stochastic general equilibrium models with rich heterogeneity, matching vari-ous aspects of the cross section such as the wealth distribution. Prominent exam-ples include Gornemann, Kuester, and Nakajima (2016); McKay, Nakamura, and Steinsson (2016); and Kaplan, Moll, and Violante (2018). These structural mod-els overcome a number of important limitations of my sufficient statistics approach. They can study the role of investment, analyze the precise interaction between mon-etary and fiscal policy, and explore the effect of shocks that are persistent and/or announced in advance. My paper makes two contributions to this literature. First, I introduce a decomposition of the monetary policy transmission mechanism into its various sources of effects on consumption that is useful to shed light on the under-lying mechanisms in any such model (see Kaplan, Moll, and Violante 2018 for an influential application). Second, I argue that sufficient statistics can discipline the construction of these models. By making sure that the model’s sufficient statistics match the data, researchers can ensure that, even if the model is misspecified, its predictions for the response of consumption to shocks are consistent with the empir-ical evidence. This paper is motivated by an extensive empirical literature documenting that MPCs are large and heterogeneous in the population (see Jappelli and Pistaferri 2010']
# chunk:  channel
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel']
# chunk:   acts in the same direction as the substitution
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ']
# chunk:  channel
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel']
# chunk:  , and with comparable magnitude provided that ​σ​ is between ​0.1​and ​0.4​. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if ​σ​ is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ']
# chunk:  channel
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel']
# chunk:  . However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, '. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity ']
# chunk:  channel
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, '. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel']
# chunk:   also amplifies the effects of monetary policy. Future work can build on these empirical results in two ways: by providing more precise measures of exposures across groups of agents or regions to inform the debate on the winners and losers from changes in monetary policy, and by estimat-ing the sufficient statistics more precisely in administrative data to help quantify the aggregate effect of this redistribution.4 A rapidly growing literature analyzes the effects of monetary policy in dynamic stochastic general equilibrium models with rich heterogeneity, matching vari-ous aspects of the cross section such as the wealth distribution. Prominent exam-ples include Gornemann, Kuester, and Nakajima (2016); McKay, Nakamura, and Steinsson (2016); and Kaplan, Moll, and Violante (2018). These structural mod-els overcome a number of important limitations of my sufficient statistics approach. They can study the role of investment, analyze the precise interaction between mon-etary and fiscal policy, and explore the effect of shocks that are persistent and/or announced in advance. My paper makes two contributions to this literature. First, I introduce a decomposition of the monetary policy transmission mechanism into its various sources of effects on consumption that is useful to shed light on the under-lying mechanisms in any such model (see Kaplan, Moll, and Violante 2018 for an influential application). Second, I argue that sufficient statistics can discipline the construction of these models. By making sure that the model’s sufficient statistics match the data, researchers can ensure that, even if the model is misspecified, its predictions for the response of consumption to shocks are consistent with the empir-ical evidence. This paper is motivated by an extensive empirical literature documenting that MPCs are large and heterogeneous in the population (see Jappelli and Pistaferri 2010
# paragraph_chunks_formatted: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, '. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' also amplifies the effects of monetary policy. Future work can build on these empirical results in two ways: by providing more precise measures of exposures across groups of agents or regions to inform the debate on the winners and losers from changes in monetary policy, and by estimat-ing the sufficient statistics more precisely in administrative data to help quantify the aggregate effect of this redistribution.4 A rapidly growing literature analyzes the effects of monetary policy in dynamic stochastic general equilibrium models with rich heterogeneity, matching vari-ous aspects of the cross section such as the wealth distribution. Prominent exam-ples include Gornemann, Kuester, and Nakajima (2016); McKay, Nakamura, and Steinsson (2016); and Kaplan, Moll, and Violante (2018). These structural mod-els overcome a number of important limitations of my sufficient statistics approach. They can study the role of investment, analyze the precise interaction between mon-etary and fiscal policy, and explore the effect of shocks that are persistent and/or announced in advance. My paper makes two contributions to this literature. First, I introduce a decomposition of the monetary policy transmission mechanism into its various sources of effects on consumption that is useful to shed light on the under-lying mechanisms in any such model (see Kaplan, Moll, and Violante 2018 for an influential application). Second, I argue that sufficient statistics can discipline the construction of these models. By making sure that the model’s sufficient statistics match the data, researchers can ensure that, even if the model is misspecified, its predictions for the response of consumption to shocks are consistent with the empir-ical evidence. This paper is motivated by an extensive empirical literature documenting that MPCs are large and heterogeneous in the population (see Jappelli and Pistaferri 2010']
# paragraph_chunks_formatted - final: [<xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' acts in the same direction as the substitution ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ', and with comparable magnitude provided that \u200bσ\u200b is between \u200b0.1\u200band \u200b0.4\u200b. Hence, representative-agent anal-yses that abstract from redistribution may fail to capture an important reason why real interest rates affect consumption, especially if \u200bσ\u200b is small.3 Similarly, across datasets, the covariance between MPCs and NNPs is negative on average. This implies that consumption tends to increase with inflation as a result of the Fisher ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, '. However, when cast in terms of elasticities, the magnitude is small: an unexpected 1 percent permanent increase in the price level raises con-sumption today by no more than 0.1 percent. This suggests that, while changes in monetary policy can entail significant nominal redistribution, the aggregate effect of this redistribution on consumption is likely to be modest. Finally, in line with previous literature, I estimate the covariance between MPCs and incomes to be negative in the data. If, in addition, low-income agents dispropor-tionately benefit from increases in aggregate income, as suggested, for example, by Coibion et al. (2017), the earnings heterogeneity ', <xlsxwriter.format.Format object at 0x0000020B4032AA30>, 'channel', <xlsxwriter.format.Format object at 0x0000020B4032A640>, ' also amplifies the effects of monetary policy. Future work can build on these empirical results in two ways: by providing more precise measures of exposures across groups of agents or regions to inform the debate on the winners and losers from changes in monetary policy, and by estimat-ing the sufficient statistics more precisely in administrative data to help quantify the aggregate effect of this redistribution.4 A rapidly growing literature analyzes the effects of monetary policy in dynamic stochastic general equilibrium models with rich heterogeneity, matching vari-ous aspects of the cross section such as the wealth distribution. Prominent exam-ples include Gornemann, Kuester, and Nakajima (2016); McKay, Nakamura, and Steinsson (2016); and Kaplan, Moll, and Violante (2018). These structural mod-els overcome a number of important limitations of my sufficient statistics approach. They can study the role of investment, analyze the precise interaction between mon-etary and fiscal policy, and explore the effect of shocks that are persistent and/or announced in advance. My paper makes two contributions to this literature. First, I introduce a decomposition of the monetary policy transmission mechanism into its various sources of effects on consumption that is useful to shed light on the under-lying mechanisms in any such model (see Kaplan, Moll, and Violante 2018 for an influential application). Second, I argue that sufficient statistics can discipline the construction of these models. By making sure that the model’s sufficient statistics match the data, researchers can ensure that, even if the model is misspecified, its predictions for the response of consumption to shocks are consistent with the empir-ical evidence. This paper is motivated by an extensive empirical literature documenting that MPCs are large and heterogeneous in the population (see Jappelli and Pistaferri 2010']

# %%
# Initial function to split paragraphs by 1 keyword, simplistic
def split_paragraph_by_keyword_simple(keyword, paragraph):
    paragraph = re.split(keyword, paragraph, flags=re.IGNORECASE)
    return paragraph

# %%
split_paragraph_by_keywordlist(keywordlist, "ausdhijkchannelasd chan channels import-CHANNEL-s channe-l channel-effect")
# Out:
# number_of_keywords_in_paragraph:  4
# ['ausdhijk',
#  'channel',
#  'asd chan ',
#  'channel',
#  's import-',
#  'CHANNEL',
#  '-s channe-l ',
#  'channel',
#  '-effect']

# %%
any('channela'.lower() == keyword for keyword in keywordlist)
# Out:
# False

# %%
any('channel'.lower() == keyword for keyword in keywordlist)
# Out:
# True

# %%
any('CHANNEL'.lower() == keyword for keyword in keywordlist)
# Out:
# True

# %%
#Test
split_paragraph_by_keyword(keyword, "ausdhijkchannelasd chan channels import-CHANNEL-s channe-l channel-effect")
# Out:
# ['ausdhijk', 'asd chan ', 's import-', '-s channe-l ', '-effect']

# %%
# Test
get_paragraph_segments(keyword, "ausdhijkchannelasd chan channels import-CHANNEL-s channe-l channel-effect")
# Out:
# ['ausdhijk', 'asd chan ', 's import-', '-s channe-l ', '-effect']
# [<xlsxwriter.format.Format object at 0x00000166387CBAC0>, 'ausdhijk', <xlsxwriter.format.Format object at 0x0000016638C12DC0>, 'channel', <xlsxwriter.format.Format object at 0x00000166387CBAC0>, 'asd chan ', <xlsxwriter.format.Format object at 0x0000016638C12DC0>, 'channel', <xlsxwriter.format.Format object at 0x00000166387CBAC0>, 's import-', <xlsxwriter.format.Format object at 0x0000016638C12DC0>, 'channel', <xlsxwriter.format.Format object at 0x00000166387CBAC0>, '-s channe-l ', <xlsxwriter.format.Format object at 0x0000016638C12DC0>, 'channel', <xlsxwriter.format.Format object at 0x00000166387CBAC0>, '-effect']
# [<xlsxwriter.format.Format at 0x166387cbac0>,
#  'ausdhijk',
#  <xlsxwriter.format.Format at 0x16638c12dc0>,
#  'channel',
#  <xlsxwriter.format.Format at 0x166387cbac0>,
#  'asd chan ',
#  <xlsxwriter.format.Format at 0x16638c12dc0>,
#  'channel',
#  <xlsxwriter.format.Format at 0x166387cbac0>,
#  's import-',
#  <xlsxwriter.format.Format at 0x16638c12dc0>,
#  'channel',
#  <xlsxwriter.format.Format at 0x166387cbac0>,
#  '-s channe-l ',
#  <xlsxwriter.format.Format at 0x16638c12dc0>,
#  'channel',
#  <xlsxwriter.format.Format at 0x166387cbac0>,
#  '-effect']

# %%
get_paragraph_segments(keyword, "aaachannel")
# Out:
# ['aaa', '']
# [<xlsxwriter.format.Format object at 0x00000166387CBAC0>, 'aaa', <xlsxwriter.format.Format object at 0x0000016638C12DC0>, 'channel', <xlsxwriter.format.Format object at 0x00000166387CBAC0>]
# [<xlsxwriter.format.Format at 0x166387cbac0>,
#  'aaa',
#  <xlsxwriter.format.Format at 0x16638c12dc0>,
#  'channel',
#  <xlsxwriter.format.Format at 0x166387cbac0>]

# %%
paragraph0 = channels_df.iloc[0, :]['Paragraph']
paragraph0
# Out:
# 'orthogonal to productivity, even though the only source of exogenous variation are sector-specific productivity shocks. A recent literature has demonstrated that, under certain conditions, production networks can lead firm-or sector-specific shocks to generate aggregate fluctua-tions, e.g., Horvath (2000), Carvalho (2010), Acemoglu et al. (2012), Carvalho and Gabaix (2013), Baqaee and Fahri (2019), and Carvalho and Grassi (2019). Shocks to a single sector or firm propagate to other sectors or firms through the trade of intermediate inputs. Foerster, Sartre, and Watson (2011) and Atalay (2017) quan-tify these channels, and their results suggest that sector-specific shocks can explain a substantial portion of observed aggregate output fluctuations. However, trade in intermediate inputs by itself does not induce enough correlation in production across sectors to account for all of the observed volatility of aggregate output. We show that news media can serve as a powerful additional source of sectoral comovement. A basic premise of our argument is that individual firms do not have the resources to directly observe every sector in the production network. Instead, firms rely on news media to monitor the economy on their behalf and to report the most newsworthy developments. However, even accurate reports provide only a partial picture of the economy. Such partial information, in turn, may lead firms to over-or underestimate how much of their product other firms will demand. As in Angeletos and La’O (2010, 2013), a firm that is overly optimistic about demand for its output hires too much labor. If firms across different sectors receive the same partial information via news media, over-or u nder-hiring of labor will be correlated across sectors. News media thus function as a coordination device for the economy, increasing the correlation of sectoral outputs beyond what would result from sec-tors’ trading relationships alone. We embed state-dependent news reporting in a modified version of the multisector model of Acemoglu et al. (2012). In our model, news media act as information inter-mediaries that relay information about the state of the economy to firms. We argue that there are two aspects of this role that are particularly relevant for understanding business cycles. First, news organizations monitor the economy by collecting and producing information about a large number of events. Second, they make editorial decisions about which events are sufficiently newsworthy to be reported.1 We for-malize these editorial decisions using news selection functions, first introduced in Nimark and Pitschner (2019). A news selection function is a mapping from the state of the world to a vector of reported outcomes. News selection functions provide a flexible way to model state-dependent editorial decisions, thereby capturing the changing focus of news coverage over time. By determining what gets reported in which states of the world, a news selec-tion function implicitly defines a notion of newsworthiness. A given notion of newsworthiness, in turn, implies a specific selection bias of events that end up in'

# %%
paragraph0_split = split_paragraph_by_keyword(keyword, paragraph0)
paragraph0_split
# Out:
# ['orthogonal to productivity, even though the only source of exogenous variation are sector-specific productivity shocks. a recent literature has demonstrated that, under certain conditions, production networks can lead firm-or sector-specific shocks to generate aggregate fluctua-tions, e.g., horvath (2000), carvalho (2010), acemoglu et al. (2012), carvalho and gabaix (2013), baqaee and fahri (2019), and carvalho and grassi (2019). shocks to a single sector or firm propagate to other sectors or firms through the trade of intermediate inputs. foerster, sartre, and watson (2011) and atalay (2017) quan-tify these ',
#  's, and their results suggest that sector-specific shocks can explain a substantial portion of observed aggregate output fluctuations. however, trade in intermediate inputs by itself does not induce enough correlation in production across sectors to account for all of the observed volatility of aggregate output. we show that news media can serve as a powerful additional source of sectoral comovement. a basic premise of our argument is that individual firms do not have the resources to directly observe every sector in the production network. instead, firms rely on news media to monitor the economy on their behalf and to report the most newsworthy developments. however, even accurate reports provide only a partial picture of the economy. such partial information, in turn, may lead firms to over-or underestimate how much of their product other firms will demand. as in angeletos and la’o (2010, 2013), a firm that is overly optimistic about demand for its output hires too much labor. if firms across different sectors receive the same partial information via news media, over-or u nder-hiring of labor will be correlated across sectors. news media thus function as a coordination device for the economy, increasing the correlation of sectoral outputs beyond what would result from sec-tors’ trading relationships alone. we embed state-dependent news reporting in a modified version of the multisector model of acemoglu et al. (2012). in our model, news media act as information inter-mediaries that relay information about the state of the economy to firms. we argue that there are two aspects of this role that are particularly relevant for understanding business cycles. first, news organizations monitor the economy by collecting and producing information about a large number of events. second, they make editorial decisions about which events are sufficiently newsworthy to be reported.1 we for-malize these editorial decisions using news selection functions, first introduced in nimark and pitschner (2019). a news selection function is a mapping from the state of the world to a vector of reported outcomes. news selection functions provide a flexible way to model state-dependent editorial decisions, thereby capturing the changing focus of news coverage over time. by determining what gets reported in which states of the world, a news selec-tion function implicitly defines a notion of newsworthiness. a given notion of newsworthiness, in turn, implies a specific selection bias of events that end up in']

# %%
# Out:
# 2

# %%
paragraph_segments = []
for index, chunk in enumerate(paragraph0_split):
    paragraph_segments.append(chunk)
    if index < len(paragraph0_split) - 1:
        paragraph_segments.append(bold_format_paragraph)
        paragraph_segments.append(keyword)    
print(paragraph_segments)
# Out:
# ['orthogonal to productivity, even though the only source of exogenous variation are sector-specific productivity shocks. a recent literature has demonstrated that, under certain conditions, production networks can lead firm-or sector-specific shocks to generate aggregate fluctua-tions, e.g., horvath (2000), carvalho (2010), acemoglu et al. (2012), carvalho and gabaix (2013), baqaee and fahri (2019), and carvalho and grassi (2019). shocks to a single sector or firm propagate to other sectors or firms through the trade of intermediate inputs. foerster, sartre, and watson (2011) and atalay (2017) quan-tify these ', <xlsxwriter.format.Format object at 0x00000166375556D0>, 'channel', 's, and their results suggest that sector-specific shocks can explain a substantial portion of observed aggregate output fluctuations. however, trade in intermediate inputs by itself does not induce enough correlation in production across sectors to account for all of the observed volatility of aggregate output. we show that news media can serve as a powerful additional source of sectoral comovement. a basic premise of our argument is that individual firms do not have the resources to directly observe every sector in the production network. instead, firms rely on news media to monitor the economy on their behalf and to report the most newsworthy developments. however, even accurate reports provide only a partial picture of the economy. such partial information, in turn, may lead firms to over-or underestimate how much of their product other firms will demand. as in angeletos and la’o (2010, 2013), a firm that is overly optimistic about demand for its output hires too much labor. if firms across different sectors receive the same partial information via news media, over-or u nder-hiring of labor will be correlated across sectors. news media thus function as a coordination device for the economy, increasing the correlation of sectoral outputs beyond what would result from sec-tors’ trading relationships alone. we embed state-dependent news reporting in a modified version of the multisector model of acemoglu et al. (2012). in our model, news media act as information inter-mediaries that relay information about the state of the economy to firms. we argue that there are two aspects of this role that are particularly relevant for understanding business cycles. first, news organizations monitor the economy by collecting and producing information about a large number of events. second, they make editorial decisions about which events are sufficiently newsworthy to be reported.1 we for-malize these editorial decisions using news selection functions, first introduced in nimark and pitschner (2019). a news selection function is a mapping from the state of the world to a vector of reported outcomes. news selection functions provide a flexible way to model state-dependent editorial decisions, thereby capturing the changing focus of news coverage over time. by determining what gets reported in which states of the world, a news selec-tion function implicitly defines a notion of newsworthiness. a given notion of newsworthiness, in turn, implies a specific selection bias of events that end up in']

# %%
# Out:
# C:\Users\jasonjia\Anaconda3\lib\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
